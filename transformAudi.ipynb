# %%
import pandas as pd
import json

# %%
audi_file = pd.read_json('20180925101535_label3D_frontcenter_000011230.json')

# %%
audi_file.head()
# Out:
#                                                        box_0  \
# 2d_bbox             [1083.448, 662.8432, 1285.339, 845.3809]
# 3d_points  [[21.055281647689508, -1.847072728745537, -1.8...
# alpha                                                      0
# axis       [7.381410761856192e-07, 7.381410761856192e-07,...
# center     [23.290400346484, -2.89027428010409, -0.822700...
#
#                                                        box_1  \
# 2d_bbox              [1120.21, 689.4951, 1360.183, 894.4734]
# 3d_points  [[15.98135, -1.819799999999999, -1.88435], [19...
# alpha                                                      0
# axis                                         [1.0, 0.0, 0.0]
# center               [17.91635, -2.7798, -0.969349999999999]
#
#                                                        box_2  \
# 2d_bbox              [1157.44, 722.7399, 1511.514, 959.7899]
# 3d_points  [[11.764003719419058, -1.814230754120784, -1.8...
# ...

# %%
len(audi_file)
# Out:
# 11

# %%
audi_file
# Out:
#                                                         box_0  \
# 2d_bbox              [1083.448, 662.8432, 1285.339, 845.3809]
# 3d_points   [[21.055281647689508, -1.847072728745537, -1.8...
# alpha                                                       0
# axis        [7.381410761856192e-07, 7.381410761856192e-07,...
# center      [23.290400346484, -2.89027428010409, -0.822700...
# class                                                     Car
# id                                                          0
# occlusion                                                   2
# rot_angle                                           0.0142748
# size                                       [4.44, 2.15, 2.15]
# truncation                                                  0
#
#                                                         box_1  \
# 2d_bbox               [1120.21, 689.4951, 1360.183, 894.4734]
# 3d_points   [[15.98135, -1.819799999999999, -1.88435], [19...
# ...

# %%
list(audi_file)
# Out:
# ['box_0',
#  'box_1',
#  'box_2',
#  'box_3',
#  'box_4',
#  'box_5',
#  'box_6',
#  'box_7',
#  'box_8']

# %%
columns = list(audi_file)

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
#                                                         box_0  \
# center      [23.290400346484, -2.89027428010409, -0.822700...
# class                                                     Car
# id                                                          0
# occlusion                                                   2
# rot_angle                                           0.0142748
# size                                       [4.44, 2.15, 2.15]
# truncation                                                  0
#
#                                               box_1  \
# center      [17.91635, -2.7798, -0.969349999999999]
# class                                           Car
# id                                                1
# occlusion                                         2
# rot_angle                                         0
# size                             [3.87, 1.92, 1.83]
# truncation                                        0
#
# ...

# %%
df2 = df.loc[['center','class','id', 'rot_angle', 'size']]

# %%
df2
# Out:
#                                                        box_0  \
# center     [23.290400346484, -2.89027428010409, -0.822700...
# class                                                    Car
# id                                                         0
# rot_angle                                          0.0142748
# size                                      [4.44, 2.15, 2.15]
#
#                                              box_1  \
# center     [17.91635, -2.7798, -0.969349999999999]
# class                                          Car
# id                                               1
# rot_angle                                        0
# size                            [3.87, 1.92, 1.83]
#
#                                                        box_2  \
# center     [13.6893001118209, -2.79426075437815, -1.07599...
# class                                                    Car
# id                                                         2
# ...

# %%
schema = pd.DataFrame(index=range(9))

# %%
schema.columns = ['sample_id', 'object_id', 'center_x', 'center_y', 'center_z', 'width', 'length', 'height', 'angle', 'object_class', 'data_location_in_s3']

# %%
for label,row in schema.iterrows():
    row[0] = '000011230'

# %%
cols = list(df2)
for val in cols:
    schema.append({'id' : df2[val][1]}, ignore_index=True)

# %%
schema
# Out:
#    sample_id object_id center_x center_y center_z width length height angle  \
# 0  000011230       NaN      NaN      NaN      NaN   NaN    NaN    NaN   NaN
# 1  000011230       NaN      NaN      NaN      NaN   NaN    NaN    NaN   NaN
# 2  000011230       NaN      NaN      NaN      NaN   NaN    NaN    NaN   NaN
# 3  000011230       NaN      NaN      NaN      NaN   NaN    NaN    NaN   NaN
# 4  000011230       NaN      NaN      NaN      NaN   NaN    NaN    NaN   NaN
# 5  000011230       NaN      NaN      NaN      NaN   NaN    NaN    NaN   NaN
# 6  000011230       NaN      NaN      NaN      NaN   NaN    NaN    NaN   NaN
# 7  000011230       NaN      NaN      NaN      NaN   NaN    NaN    NaN   NaN
# 8  000011230       NaN      NaN      NaN      NaN   NaN    NaN    NaN   NaN
#
#   object_class data_location_in_s3
# 0          NaN                 NaN
# 1          NaN                 NaN
# 2          NaN                 NaN
# 3          NaN                 NaN
# ...

# %%
df2.value
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-97-edb67a575bb6> in <module>
# ----> 1 df2.value
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'value'
